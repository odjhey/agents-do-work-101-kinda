# %%
import pandas as pd

# %%
df = pd.read_csv("../job_postings.csv")
df.shape
# Out:
# (200, 5)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'job_id', 'title', 'description', 'company_name'], dtype='str')

# %%
v = df[df["Unnamed: 0"] == 82]
print(v)
v = v["description"].values[0]
# Out:
#     Unnamed: 0      job_id              title  \
# 82          82  3634090513  Software Engineer
#
#                                           description company_name
# 82  Step into a realm where innovation merges seam...  Salesfinity

# %%
import textwrap
print(textwrap.fill(v, 80))
# Out:
# Step into a realm where innovation merges seamlessly with technology, much like
# a Spielberg masterpiece captivating hearts worldwide. Embark on a journey with
# us at Salesfinity AI, a symphony of artificial intelligence and parallel dialer
# prowess, designed to propel companies toward unparalleled growth and the
# realization of their dreams. As a maestro of code in the role of Full Stack
# Engineer at Salesfinity, you'll be the composer of change, orchestrating a
# revolution in sales automation. Picture yourself in the heart of San Francisco,
# our B2B SaaS startup's home, where we are on a dedicated mission to empower
# sales teams with the magic of real-time customer interactions and streamlined
# workflows. If your expertise in the realms of backend mysticism includes the
# wizardry of Node.js, an artful dance with AWS, and the craftsmanship of crafting
# REST APIs, then this role is your destined stage. Your Crescendo:Your hands,
# ...
